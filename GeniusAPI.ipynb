# %%
import requests
from pprint import pprint as pp

# %%
url = 'https://api.genius.com/search?q=Kendrick%20Lamar'
headers = {'Authorization':'Bearer zBLrMluLf2_S2mM4aLwA8Bjf08IDG2D8MWzf2zmuKJoxCvllpr9iJI1G0PPF8sGh'}
resp = requests.get(url, headers=headers)
resp = resp.json()['response']['hits'][0]['result']
pp(resp)
# Out:
# {'annotation_count': 20,
#  'api_path': '/songs/3039923',
#  'full_title': 'HUMBLE. by\xa0Kendrick\xa0Lamar',
#  'header_image_thumbnail_url': 'https://images.genius.com/039eed0758eb3aa30f050c77e7bbdc1e.300x300x1.jpg',
#  'header_image_url': 'https://images.genius.com/039eed0758eb3aa30f050c77e7bbdc1e.1000x1000x1.jpg',
#  'id': 3039923,
#  'lyrics_owner_id': 104344,
#  'lyrics_state': 'complete',
#  'path': '/Kendrick-lamar-humble-lyrics',
#  'primary_artist': {'api_path': '/artists/1421',
#                     'header_image_url': 'https://images.genius.com/3d4bc53cfb5f00d5f6a70e19960cc881.1000x1000x1.jpg',
#                     'id': 1421,
#                     'image_url': 'https://images.genius.com/eb0ad077e281e41ccd28b400e38061d2.1000x1000x1.jpg',
#                     'iq': 31096,
#                     'is_meme_verified': True,
#                     'is_verified': True,
#                     'name': 'Kendrick Lamar',
# ...

# %%
url = 'https://api.genius.com/songs/3039923'
resp = requests.get(url, headers=headers)
resp = resp.json()
pp(resp)
# Out:
# {'meta': {'status': 200},
#  'response': {'song': {'album': {'api_path': '/albums/337082',
#                                  'artist': {'api_path': '/artists/1421',
#                                             'header_image_url': 'https://images.genius.com/3d4bc53cfb5f00d5f6a70e19960cc881.1000x1000x1.jpg',
#                                             'id': 1421,
#                                             'image_url': 'https://images.genius.com/eb0ad077e281e41ccd28b400e38061d2.1000x1000x1.jpg',
#                                             'iq': 31096,
#                                             'is_meme_verified': True,
#                                             'is_verified': True,
#                                             'name': 'Kendrick Lamar',
#                                             'url': 'https://genius.com/artists/Kendrick-lamar'},
# ...
